# %% [markdown]
# # NBA Win-Loss Modeling Data Prep

# %% [markdown]
# This Jupyter Notebook script will walk you through the process of engineering features using Team, Player, and Game data for the purpose of creating an NBA Home Team Win-Loss Binary Classification Model. Follow the link for inuition around the model https://medium.com/@theresearchlab/create-an-nba-win-loss-model-w-68-precision-d1c6a21f0ded

# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import cumestatsteamgames, cumestatsteam, gamerotation
import pandas as pd
import numpy as np
import json
import difflib
import time
import requests
import _thread
import threading

# %% [markdown]
# implement a retry wrapper using a python decorator function. This will prevent the HTTP Timeouts from stopping the script's run during API calls.

# %%
# Retry Wrapper 
def retry(func, retries=3):
    def retry_wrapper(*args, **kwargs):
        attempts = 0
        while attempts < retries:
            try:
                return func(*args, **kwargs)
            except requests.exceptions.RequestException as e:
                print(e)
                time.sleep(30)
                attempts += 1

    return retry_wrapper

# %%
# Get Season Schedule Function 

def getSeasonScheduleFrame(seasons,seasonType): 

    # Get date from string
    def getGameDate(matchup):
        return matchup.partition(' at')[0][:10]

    # Get Home team from string
    def getHomeTeam(matchup):
        return matchup.partition(' at')[2]

    # Get Away team from string
    def getAwayTeam(matchup):
        return matchup.partition(' at')[0][10:]

    # Match nickname from schedule to team table to find ID
    def getTeamIDFromNickname(nickname):
        return teamLookup.loc[teamLookup['nickname'] == difflib.get_close_matches(nickname,teamLookup['nickname'],1)[0]].values[0][0] 
    
    @retry
    def getRegularSeasonSchedule(season,teamID,seasonType):
        season = str(season) + "-" + str(season+1)[-2:] # Convert year to season format ie. 2020 -> 2020-21
        teamGames = cumestatsteamgames.CumeStatsTeamGames(league_id = '00',season = season ,
                                                                      season_type_all_star=seasonType,
                                                                      team_id = teamID).get_normalized_json()

        teamGames = pd.DataFrame(json.loads(teamGames)['CumeStatsTeamGames'])
        teamGames['SEASON'] = season
        return teamGames    
    
    # Get team lookup table
    teamLookup = pd.DataFrame(teams.get_teams())
    
    # Get teams schedule for each team for each season
    scheduleFrame = pd.DataFrame()

    for season in seasons:
        for id in teamLookup['id']:
            time.sleep(1)
            scheduleFrame = pd.concat([scheduleFrame, getRegularSeasonSchedule(season,id,seasonType)])
            
    scheduleFrame['GAME_DATE'] = pd.to_datetime(scheduleFrame['MATCHUP'].map(getGameDate))
    scheduleFrame['HOME_TEAM_NICKNAME'] = scheduleFrame['MATCHUP'].map(getHomeTeam)
    scheduleFrame['HOME_TEAM_ID'] = scheduleFrame['HOME_TEAM_NICKNAME'].map(getTeamIDFromNickname)
    scheduleFrame['AWAY_TEAM_NICKNAME'] = scheduleFrame['MATCHUP'].map(getAwayTeam)
    scheduleFrame['AWAY_TEAM_ID'] = scheduleFrame['AWAY_TEAM_NICKNAME'].map(getTeamIDFromNickname)
    scheduleFrame = scheduleFrame.drop_duplicates() # There's a row for both teams, only need 1
    scheduleFrame = scheduleFrame.reset_index(drop=True)
            
    return scheduleFrame

# %%
# Get Single Game aggregation columns

def getSingleGameMetrics(gameID,homeTeamID,awayTeamID,awayTeamNickname,seasonYear,gameDate):

    @retry
    def getGameStats(teamID,gameID,seasonYear):
        gameStats = cumestatsteam.CumeStatsTeam(game_ids=gameID,league_id ="00",
                                               season=seasonYear,season_type_all_star="Regular Season",
                                               team_id = teamID).get_normalized_json()

        gameStats = pd.DataFrame(json.loads(gameStats)['TotalTeamStats'])

        return gameStats

    data = getGameStats(homeTeamID,gameID,seasonYear)
    data.at[1,'NICKNAME'] = awayTeamNickname
    data.at[1,'TEAM_ID'] = awayTeamID
    data.at[1,'OFFENSIVE_EFFICIENCY'] = (data.at[1,'FG'] + data.at[1,'AST'])/(data.at[1,'FGA'] - data.at[1,'OFF_REB'] + data.at[1,'AST'] + data.at[1,'TOTAL_TURNOVERS'])
    data.at[1,'SCORING_MARGIN'] = data.at[1,'PTS'] - data.at[0,'PTS']

    data.at[0,'OFFENSIVE_EFFICIENCY'] = (data.at[0,'FG'] + data.at[0,'AST'])/(data.at[0,'FGA'] - data.at[0,'OFF_REB'] + data.at[0,'AST'] + data.at[0,'TOTAL_TURNOVERS'])
    data.at[0,'SCORING_MARGIN'] = data.at[0,'PTS'] - data.at[1,'PTS']

    data['SEASON'] = seasonYear
    data['GAME_DATE'] = gameDate
    data['GAME_ID'] = gameID

    return data

# %%
def getGameLogs(gameLogs,scheduleFrame):
    
    thread_lock = threading.Lock()
    # Functions to prepare additional columns after gameLogs table loads
    def getHomeAwayFlag(gameDF):
        gameDF['HOME_FLAG'] = np.where((gameDF['W_HOME']==1) | (gameDF['L_HOME']==1),1,0)
        gameDF['AWAY_FLAG'] = np.where((gameDF['W_ROAD']==1) | (gameDF['L_ROAD']==1),1,0) 

    def getTotalWinPctg(gameDF):
        gameDF['TOTAL_GAMES_PLAYED'] = gameDF.groupby(['TEAM_ID','SEASON'])['GAME_DATE'].rank(ascending=True)
        gameDF['TOTAL_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W'].cumsum()
        gameDF['TOTAL_WIN_PCTG'] = gameDF['TOTAL_WINS']/gameDF['TOTAL_GAMES_PLAYED']
        return gameDF.drop(['TOTAL_GAMES_PLAYED','TOTAL_WINS'],axis=1)

    def getHomeWinPctg(gameDF):
        gameDF['HOME_GAMES_PLAYED'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['HOME_FLAG'].cumsum()
        gameDF['HOME_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W_HOME'].cumsum()
        gameDF['HOME_WIN_PCTG'] = gameDF['HOME_WINS']/gameDF['HOME_GAMES_PLAYED']
        return gameDF.drop(['HOME_GAMES_PLAYED','HOME_WINS'],axis=1)

    def getAwayWinPctg(gameDF):
        gameDF['AWAY_GAMES_PLAYED'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['AWAY_FLAG'].cumsum()
        gameDF['AWAY_WINS'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['W_ROAD'].cumsum()
        gameDF['AWAY_WIN_PCTG'] = gameDF['AWAY_WINS']/gameDF['AWAY_GAMES_PLAYED']
        return gameDF.drop(['AWAY_GAMES_PLAYED','AWAY_WINS'],axis=1)

    def getRollingOE(gameDF):
        gameDF['ROLLING_OE'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['OFFENSIVE_EFFICIENCY'].transform(lambda x: x.rolling(3, 1).mean())

    def getRollingScoringMargin(gameDF):
        gameDF['ROLLING_SCORING_MARGIN'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['SCORING_MARGIN'].transform(lambda x: x.rolling(3, 1).mean())

    def getRestDays(gameDF):
        gameDF['LAST_GAME_DATE'] = gameDF.sort_values(by='GAME_DATE').groupby(['TEAM_ID','SEASON'])['GAME_DATE'].shift(1)
        gameDF['NUM_REST_DAYS'] = (gameDF['GAME_DATE'] - gameDF['LAST_GAME_DATE'])/np.timedelta64(1,'D') 
        return gameDF.drop('LAST_GAME_DATE',axis=1)

    def collect_and_process_game_data(i):
        with thread_lock:
                # Replace the body of your while loop here
            time.sleep(1)
            gameLogs = pd.concat([getSingleGameMetrics(scheduleFrame.at[i, 'GAME_ID'], scheduleFrame.at[i, 'HOME_TEAM_ID'],
                                                        scheduleFrame.at[i, 'AWAY_TEAM_ID'], scheduleFrame.at[i, 'AWAY_TEAM_NICKNAME'],
                                                        scheduleFrame.at[i, 'SEASON'], scheduleFrame.at[i, 'GAME_DATE']), gameLogs])
            gameLogs = gameLogs.reset_index(drop=True)
        
    # start = time.perf_counter_ns()
    # i = int(len(gameLogs) / 2)

    # while i < len(scheduleFrame):
    #     # 使用线程池来控制并发线程数量
    #     thread = threading.Thread(target=collect_and_process_game_data, args=(i,))
    #     thread.start()
    #     thread.join()  # 等待线程完成
    
    #     end = time.perf_counter_ns()

    #     if i % 100 == 0:
    #         mins = ((end - start) / 1e9) / 60
    #         print(i, str(mins) + ' minutes')

    #     i += 1

    
    start = time.perf_counter_ns()

    i = int(len(gameLogs)/2) #Can use a previously completed gameLog dataset

    while i<len(scheduleFrame):


        time.sleep(1)
        gameLogs =  pd.concat([getSingleGameMetrics(scheduleFrame.at[i,'GAME_ID'],scheduleFrame.at[i,'HOME_TEAM_ID'],
                         scheduleFrame.at[i,'AWAY_TEAM_ID'],scheduleFrame.at[i,'AWAY_TEAM_NICKNAME'],
                         scheduleFrame.at[i,'SEASON'],scheduleFrame.at[i,'GAME_DATE']),gameLogs])
        
        gameLogs = gameLogs.reset_index(drop=True)

        end = time.perf_counter_ns()

        #Output time it took to load x amount of records
        if i%100 == 0:
            mins = ((end-start)/1e9)/60
            print(i,str(mins) + ' minutes')

        i+=1
        
    # Get Table Level Aggregation Columns
    getHomeAwayFlag(gameLogs)
    gameLogs = getHomeWinPctg(gameLogs)
    gameLogs = getAwayWinPctg(gameLogs)
    gameLogs = getTotalWinPctg(gameLogs)
    getRollingScoringMargin(gameLogs)
    getRollingOE(gameLogs)
    gameLogs = getRestDays(gameLogs)

    return gameLogs.reset_index(drop=True)

# %%
#Get ScheduleFrame

seasons = range(2021,2023)
seasonType = 'Regular Season'

start = time.perf_counter_ns() # Track cell's runtime
scheduleFrame = getSeasonScheduleFrame(seasons,seasonType)
end = time.perf_counter_ns()

secs = (end-start)/1e9
mins = secs/60
print(mins)
# Out:
# 1.10535948125

# %%
#Example Output of Single Game Metrics
getSingleGameMetrics(scheduleFrame.at[104,'GAME_ID'],scheduleFrame.at[104,'HOME_TEAM_ID'],
                     scheduleFrame.at[104,'AWAY_TEAM_ID'],scheduleFrame.at[104,'AWAY_TEAM_NICKNAME'],
                     scheduleFrame.at[104,'SEASON'],scheduleFrame.at[104,'GAME_DATE'])
# Out:
#            CITY  NICKNAME     TEAM_ID  W  L  W_HOME  L_HOME  W_ROAD  L_ROAD
# 0  Philadelphia     76ers  1610612755  0  1       0       1       0       0  \
# 1     OPPONENTS   Celtics  1610612738  1  0       0       0       1       0
#
#    TEAM_TURNOVERS  ...  BLK  PTS  AVG_REB  AVG_PTS  DQ  OFFENSIVE_EFFICIENCY
# 0               0  ...    2   87     47.0     87.0   0              0.425532  \
# 1               2  ...   10  135     56.0    135.0   0              0.649123
#
#    SCORING_MARGIN   SEASON  GAME_DATE     GAME_ID
# 0           -48.0  2021-22 2022-02-15  0022100869
# 1            48.0  2021-22 2022-02-15  0022100869
#
# [2 rows x 41 columns]

# %%
#Create the gameLogs DataFrame
gameLogs = pd.DataFrame()
gameLogs = getGameLogs(gameLogs,scheduleFrame)
gameLogs.to_csv('gameLogs.csv')
# Out:
# Exception in thread Thread-2464 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# 0 0.018608790266666668 minutes
# Exception in thread Thread-2465 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2466 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2467 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2468 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2469 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2470 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2471 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2472 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2473 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2474 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2475 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2476 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2477 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2478 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2479 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2480 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2481 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2482 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2483 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2484 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2485 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2486 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2487 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2488 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2489 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2490 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2491 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2492 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2493 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2494 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2495 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2496 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2497 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2498 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2499 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2500 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2501 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2502 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2503 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2504 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2505 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2506 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2507 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2508 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2509 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2510 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2511 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2512 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2513 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2514 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2515 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2516 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2517 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2518 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2519 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2520 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2521 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2522 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2523 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2524 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2525 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2526 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2527 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2528 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2529 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2530 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2531 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2532 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2533 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2534 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2535 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2536 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2537 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2538 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2539 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2540 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-2541 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3003 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3004 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3005 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3006 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3007 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3008 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3009 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3010 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3011 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3012 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3013 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3014 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3015 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3016 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3017 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3018 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3019 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3020 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3021 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# Exception in thread Thread-3022 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/andyfei/Downloads/Home Team Win-Loss Data Prep.ipynb 单元格 11 line 3
#       <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> #Create the gameLogs DataFrame
#       <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> gameLogs = pd.DataFrame()
# ----> <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> gameLogs = getGameLogs(gameLogs,scheduleFrame)
#       <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> gameLogs.to_csv('gameLogs.csv')
#
# /Users/andyfei/Downloads/Home Team Win-Loss Data Prep.ipynb 单元格 11 line 5
#      <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=51'>52</a> thread = threading.Thread(target=collect_and_process_game_data, args=(i,))
#      <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=52'>53</a> thread.start()
# ---> <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=53'>54</a> thread.join()  # 等待线程完成
#      <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=55'>56</a> end = time.perf_counter_ns()
#      <a href='vscode-notebook-cell:/Users/andyfei/Downloads/Home%20Team%20Win-Loss%20Data%20Prep.ipynb#X13sZmlsZQ%3D%3D?line=57'>58</a> if i % 100 == 0:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1112, in Thread.join(self, timeout)
#    1109     raise RuntimeError("cannot join current thread")
#    1111 if timeout is None:
# -> 1112     self._wait_for_tstate_lock()
#    1113 else:
#    1114     # the behavior of a negative timeout isn't documented, but
#    1115     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1116     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:1132, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1129     return
#    1131 try:
# -> 1132     if lock.acquire(block, timeout):
#    1133         lock.release()
#    1134         self._stop()
#
# KeyboardInterrupt:
# Exception in thread Thread-3023 (collect_and_process_game_data):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/hb/mm2f8qn96wq2gxmqm25nw7d00000gn/T/ipykernel_52171/3070503857.py", line 44, in collect_and_process_game_data
# UnboundLocalError: cannot access local variable 'gameLogs' where it is not associated with a value

# %%
#Example Output of Game Logs
gameLogs[(gameLogs['TEAM_ID'] == 1610612737 ) & (gameLogs['SEASON'] == '2022-23')].sort_values('GAME_DATE')

# %% [markdown]
# ## Feature Engineered Dataset
# This function produces the dataset with all current feature variables for modeling and additional columns to perform a training set/validation set split.

# %%
def getGameLogFeatureSet(gameDF):

    def shiftGameLogRecords(gameDF):
        gameDF['LAST_GAME_OE'] = gameLogs.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['OFFENSIVE_EFFICIENCY'].shift(1)
        gameDF['LAST_GAME_HOME_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['HOME_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_AWAY_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['AWAY_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_TOTAL_WIN_PCTG'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['TOTAL_WIN_PCTG'].shift(1)
        gameDF['LAST_GAME_ROLLING_SCORING_MARGIN'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['ROLLING_SCORING_MARGIN'].shift(1)
        gameDF['LAST_GAME_ROLLING_OE'] = gameDF.sort_values('GAME_DATE').groupby(['TEAM_ID','SEASON'])['ROLLING_OE'].shift(1)
    
    
    def getHomeTeamFrame(gameDF):
        homeTeamFrame = gameDF[gameDF['CITY'] != 'OPPONENTS']
        homeTeamFrame = homeTeamFrame[['LAST_GAME_OE','LAST_GAME_HOME_WIN_PCTG','NUM_REST_DAYS','LAST_GAME_AWAY_WIN_PCTG','LAST_GAME_TOTAL_WIN_PCTG','LAST_GAME_ROLLING_SCORING_MARGIN','LAST_GAME_ROLLING_OE','W','TEAM_ID','GAME_ID','SEASON']]

        colRenameDict = {}
        for col in homeTeamFrame.columns:
            if (col != 'GAME_ID') & (col != 'SEASON') :
                colRenameDict[col] = 'HOME_' + col 

        homeTeamFrame.rename(columns=colRenameDict,inplace=True)

        return homeTeamFrame

    def getAwayTeamFrame(gameDF):
        awayTeamFrame = gameDF[gameDF['CITY'] == 'OPPONENTS']
        awayTeamFrame = awayTeamFrame[['LAST_GAME_OE','LAST_GAME_HOME_WIN_PCTG','NUM_REST_DAYS','LAST_GAME_AWAY_WIN_PCTG','LAST_GAME_TOTAL_WIN_PCTG','LAST_GAME_ROLLING_SCORING_MARGIN','LAST_GAME_ROLLING_OE','TEAM_ID','GAME_ID','SEASON']]

        colRenameDict = {}
        for col in awayTeamFrame.columns:
            if (col != 'GAME_ID') & (col != 'SEASON'):
                colRenameDict[col] = 'AWAY_' + col 

        awayTeamFrame.rename(columns=colRenameDict,inplace=True)

        return awayTeamFrame
    
    shiftGameLogRecords(gameLogs)
    awayTeamFrame = getAwayTeamFrame(gameLogs)
    homeTeamFrame = getHomeTeamFrame(gameLogs)
    
    return pd.merge(homeTeamFrame, awayTeamFrame, how="inner", on=[ "GAME_ID","SEASON"]).drop(['GAME_ID','AWAY_TEAM_ID','HOME_TEAM_ID'],axis=1)

# %%
modelData = getGameLogFeatureSet(gameLogs)

# %%
# Final Data Set before Train,Test, Validation Split
modelData

# %%
modelData.to_csv('nbaHomeWinLossModelDataset.csv')
